# %% [markdown]
# <a href="https://colab.research.google.com/github/suajeong52/heaveMPM/blob/main/position_0_1rad_s_AQWA%EA%B7%B8%EB%9E%98%ED%94%84%EA%B7%B8%EB%A6%AC%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **데이터 불러오기**

# %%
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-08d23276-1e87-429e-80df-a6aeb319d839" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08d23276-1e87-429e-80df-a6aeb319d839">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd

# %%
mesh1_6 = pd.read_csv(io.BytesIO(myfile['1.6MESH_P.csv']))
mesh2_2 = pd.read_csv(io.BytesIO(myfile['2.2MESH_P.csv']))
mesh2_85 = pd.read_csv(io.BytesIO(myfile['2.85MESH_P.csv']))
mesh3_25 = pd.read_csv(io.BytesIO(myfile['3.25MESH_P.csv']))

# %%
print(mesh1_6)
print(mesh2_2)
print(mesh2_85)
print(mesh3_25)
# Out:
#               t         m
# 0       0.00000  6.103985
# 1       0.10000  6.103976
# 2       0.20000  6.103943
# 3       0.30000  6.103880
# 4       0.40000  6.103783
# ...         ...       ...
# 4996  499.60001  6.096753
# 4997  499.70001  6.096889
# 4998  499.80002  6.097101
# 4999  499.89999  6.097380
# 5000  500.00000  6.097715
#
# [5001 rows x 2 columns]
#               t         m
# 0       0.00000  6.103985
# 1       0.10000  6.103969
# 2       0.20000  6.103914
# 3       0.30000  6.103816
# 4       0.40000  6.103668
# ...         ...       ...
# 4996  499.60001  6.095879
# 4997  499.70001  6.096065
# 4998  499.80002  6.096316
# 4999  499.89999  6.096622
# 5000  500.00000  6.096972
#
# [5001 rows x 2 columns]
#               t         m
# 0       0.00000  6.103985
# 1       0.10000  6.103969
# 2       0.20000  6.103914
# 3       0.30000  6.103815
# 4       0.40000  6.103667
# ...         ...       ...
# 4996  499.60001  6.097398
# 4997  499.70001  6.097596
# ...

# %%
t_16 = mesh1_6['t']
m_16 = mesh1_6['m']

t_22 = mesh2_2['t']
m_22 = mesh2_2['m']

t_285 = mesh2_85['t']
m_285 = mesh2_85['m']

t_325 = mesh3_25['t']
m_325 = mesh3_25['m']

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(t_16, m_16, label='mesh_1.6')
plt.plot(t_22, m_22, label='mesh_2.2')
plt.plot(t_285, m_285, label='mesh_2.85')
plt.plot(t_325, m_325, label='mesh_3.25')



plt.xlabel('Time')
plt.ylabel('HEAVE Position')
plt.legend(loc='lower right')


plt.show()
