# %% [markdown]
# <a href="https://colab.research.google.com/github/suajeong52/heaveMPM/blob/main/diff_frquency2_85_RAO_0405.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **데이터 불러오기**

# %%
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-373c3ddb-048e-4226-9776-48df3f881fc3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-373c3ddb-048e-4226-9776-48df3f881fc3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd

# %%
diff5 = pd.read_csv(io.BytesIO(myfile['2.85_f5_diffractionRAO.csv']))
diff11 = pd.read_csv(io.BytesIO(myfile['2.85_f11_diffractionRAO.csv']))
diff17 = pd.read_csv(io.BytesIO(myfile['2.85_f17_diffractionRAO.csv']))
diff35 = pd.read_csv(io.BytesIO(myfile['2.85_f35_diffractionRAO.csv']))
diff71 = pd.read_csv(io.BytesIO(myfile['2.85_f71_diffractionRAO.csv']))

# %%
f5 = diff5['f']
m5 = diff5['m']

f11 = diff11['f']
m11 = diff11['m']

f17 = diff17['f']
m17 = diff17['m']

f35 = diff35['f']
m35 = diff35['m']

f71 = diff71['f']
m71 = diff71['m']

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(f5,m5, label='7')
plt.plot(f11,m11, label='13')
plt.plot(f17,m17, label='19')
plt.plot(f35,m35, label='37')
plt.plot(f71,m71, label='73')

plt.xlabel('frequency(rad/s)')
plt.ylabel('RAO')
plt.legend(loc='lower right')
plt.show()

# %%
plt.plot(f5,m5, marker='o',label='7')
plt.plot(f11,m11, label='13')
plt.plot(f17,m17, label='19')
plt.plot(f35,m35, label='37')
plt.plot(f71,m71, label='73')

# %%
plt.plot(f11,m11,marker='o', label='13')
plt.plot(f17,m17, label='19')
plt.plot(f35,m35, label='37')
plt.plot(f71,m71, label='73')

# %%
plt.plot(f11,m11, label='13')
plt.plot(f17,m17,marker='o', label='19')
plt.plot(f35,m35, label='37')
plt.plot(f71,m71, label='73')

# %%
plt.plot(f11,m11, label='13')
plt.plot(f17,m17, label='19')
plt.plot(f35,m35, marker='o',label='37')
plt.plot(f71,m71, label='73')

# %%
plt.plot(f11,m11, label='13')
plt.plot(f17,m17, label='19')
plt.plot(f35,m35, label='37')
plt.plot(f71,m71,marker='o', label='73')

# %%
import numpy as np
