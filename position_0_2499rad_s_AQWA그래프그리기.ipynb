# %% [markdown]
# <a href="https://colab.research.google.com/github/suajeong52/heaveMPM/blob/main/position_0_2499rad_s_AQWA%EA%B7%B8%EB%9E%98%ED%94%84%EA%B7%B8%EB%A6%AC%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **데이터 불러오기**

# %%
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-fcb8b214-7f6e-4c4c-96c3-729b309bf113" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fcb8b214-7f6e-4c4c-96c3-729b309bf113">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd

# %%
mesh1_6 = pd.read_csv(io.BytesIO(myfile['1.6MESH_0.2499_P.csv']))
mesh2_2 = pd.read_csv(io.BytesIO(myfile['2.2MESH_0.2499_P.csv']))
mesh2_85 = pd.read_csv(io.BytesIO(myfile['2.85MESH_0.2499_P.csv']))
mesh3_25 = pd.read_csv(io.BytesIO(myfile['3.25MESH_0.2499_P.csv']))

# %%
print(mesh1_6)
print(mesh2_2)
print(mesh2_85)
print(mesh3_25)
# Out:
#               t         m
# 0       0.00000  6.103985
# 1       0.10000  6.103976
# 2       0.20000  6.103945
# 3       0.30000  6.103886
# 4       0.40000  6.103793
# ...         ...       ...
# 4996  499.60001  6.115705
# 4997  499.70001  6.115983
# 4998  499.80002  6.116324
# 4999  499.89999  6.116718
# 5000  500.00000  6.117152
#
# [5001 rows x 2 columns]
#               t         m
# 0       0.00000  6.103985
# 1       0.10000  6.103969
# 2       0.20000  6.103916
# 3       0.30000  6.103821
# 4       0.40000  6.103678
# ...         ...       ...
# 4996  499.60001  6.108498
# 4997  499.70001  6.109073
# 4998  499.80002  6.109703
# 4999  499.89999  6.110375
# 5000  500.00000  6.111081
#
# [5001 rows x 2 columns]
#               t         m
# 0       0.00000  6.103985
# 1       0.10000  6.103969
# 2       0.20000  6.103916
# 3       0.30000  6.103820
# 4       0.40000  6.103676
# ...         ...       ...
# 4996  499.60001  6.109235
# 4997  499.70001  6.109833
# ...

# %%
t_16 = mesh1_6['t']
m_16 = mesh1_6['m']

t_22 = mesh2_2['t']
m_22 = mesh2_2['m']

t_285 = mesh2_85['t']
m_285 = mesh2_85['m']

t_325 = mesh3_25['t']
m_325 = mesh3_25['m']

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(t_16, m_16, label='mesh_1.6')
plt.plot(t_22, m_22, label='mesh_2.2')
plt.plot(t_285, m_285, label='mesh_2.85')
plt.plot(t_325, m_325, label='mesh_3.25')



plt.xlabel('Time')
plt.ylabel('HEAVE Position')
plt.legend(loc='lower right')


plt.show()
